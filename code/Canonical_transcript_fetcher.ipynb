# %% [markdown]
# Canonical Transcripts fetching and p. (pdots/HGVSp notation) matching and markup

# %%
# Canonical transcript fetch based on Gene symbols from Ensembl API
# Requires a gene list text file and output filepath

#!/usr/bin/env python

import sys
import json
import time
import pandas as pd

try:
    from urllib.parse import urlencode
    from urllib.request import urlopen, Request
    from urllib.error import HTTPError
except ImportError:
    from urlparse import urlparse
    from urllib import urlencode
    from urllib2 import urlopen, Request, HTTPError

class EnsemblRestClient(object):
    def __init__(self, server='http://rest.ensembl.org', reqs_per_sec=15):
        self.server = server
        self.reqs_per_sec = reqs_per_sec
        self.req_count = 0
        self.last_req = 0

    def perform_rest_action(self, endpoint, hdrs=None, params=None):
        """ Perform API request with automatic rate limiting. """
        if hdrs is None:
            hdrs = {}

        if 'Content-Type' not in hdrs:
            hdrs['Content-Type'] = 'application/json'

        if params:
            endpoint += '?' + urlencode(params)

        data = None

        # Rate limit handling
        if self.req_count >= self.reqs_per_sec:
            delta = time.time() - self.last_req
            if delta < 1:
                time.sleep(1 - delta)
            self.last_req = time.time()
            self.req_count = 0

        try:
            request = Request(self.server + endpoint, headers=hdrs)
            response = urlopen(request)
            content = response.read()
            if content:
                data = json.loads(content)
            self.req_count += 1  # Increment request count

        except HTTPError as e:
            if e.code == 429:  # Ensembl rate limiting
                if 'Retry-After' in e.headers:
                    retry = int(e.headers['Retry-After'])
                    print(f"Rate limited. Retrying after {retry} seconds...")
                    time.sleep(retry)
                    return self.perform_rest_action(endpoint, hdrs, params)
            else:
                sys.stderr.write(f"Request failed for {endpoint}: {e.code} {e.reason}\n")

        return data

    def get_canonical_transcript(self, species, symbol):
        """ Fetch canonical transcript for a given gene symbol. """
        gene_info = self.perform_rest_action(
            endpoint=f'/lookup/symbol/{species}/{symbol}', 
            params={}
        )
        if gene_info:
            return gene_info.get("canonical_transcript", "Not available")
        return "No data found"

def fetch_canonical_transcripts(gene_list_file, output_file, species="homo_sapiens"):
    """ Reads gene list, fetches canonical transcripts, and saves results. """
    try:
        with open(gene_list_file, 'r') as file:
            gene_symbols = [line.strip() for line in file if line.strip()]
    except FileNotFoundError:
        print(f"Error: File {gene_list_file} not found.")
        sys.exit(1)

    client = EnsemblRestClient()
    results = []

    for gene in gene_symbols:
        print(f"Fetching canonical transcript for {gene}...")
        canonical_transcript = client.get_canonical_transcript(species, gene)
        results.append({"Gene Symbol": gene, "Canonical Transcript": canonical_transcript})

    # Save results to Excel
    df = pd.DataFrame(results)
    df.to_excel(output_file, index=False)
    print(f"\nResults saved to {output_file}")

if __name__ == '__main__':
    gene_list_file = 'genes_abs_ind.txt'  # Update with actual file path
    output_file = 'abs_ind_gene_canonical_transcripts.xlsx'
    fetch_canonical_transcripts(gene_list_file, output_file)
# Out:
# Fetching canonical transcript for CFTR...
# Fetching canonical transcript for CTNS...
# Fetching canonical transcript for PEX12...
# Fetching canonical transcript for BMPR2...
# Fetching canonical transcript for FYCO1...
# Fetching canonical transcript for ALDH7A1...
# Fetching canonical transcript for NRAS...
# Fetching canonical transcript for VWF...
# Fetching canonical transcript for FBN1...
# Fetching canonical transcript for MAP3K1...
# Fetching canonical transcript for FARS2...
# Fetching canonical transcript for SOD1...
# Fetching canonical transcript for SDCCAG8...
# Fetching canonical transcript for HBB...
# Fetching canonical transcript for TP53...
# Fetching canonical transcript for HMBS...
# Fetching canonical transcript for GJB2...
# Fetching canonical transcript for ARHGAP11A...
# Fetching canonical transcript for POLK...
# Fetching canonical transcript for SDHC...
# Fetching canonical transcript for BCHE...
# Fetching canonical transcript for GDF6...
# Fetching canonical transcript for PKLR...
# Fetching canonical transcript for ZBTB42...
# Fetching canonical transcript for ERCC2...
# Fetching canonical transcript for PKHD1...
# Fetching canonical transcript for AGXT...
# Fetching canonical transcript for CYP4V2...
# Fetching canonical transcript for SETX...
# Fetching canonical transcript for SMAD4...
# Fetching canonical transcript for CTRC...
# Fetching canonical transcript for VPS13B...
# Fetching canonical transcript for SLC22A5...
# Fetching canonical transcript for LDLRAP1...
# Fetching canonical transcript for TTC19...
# Fetching canonical transcript for RBM10...
# Fetching canonical transcript for PTEN...
# Fetching canonical transcript for FBXW7...
# Fetching canonical transcript for CDKN2A...
# Fetching canonical transcript for PRPH2...
# Fetching canonical transcript for TBX19...
# Fetching canonical transcript for FGD1...
# Fetching canonical transcript for WARS2...
# Fetching canonical transcript for RB1...
# Fetching canonical transcript for NF2...
# Fetching canonical transcript for GRHPR...
# Fetching canonical transcript for ATM...
# Fetching canonical transcript for MYO3A...
# Fetching canonical transcript for NPC1...
# Fetching canonical transcript for NFE2L2...
# Fetching canonical transcript for PIK3CA...
# Fetching canonical transcript for KRAS...
# Fetching canonical transcript for UNC80...
# Fetching canonical transcript for SI...
# Fetching canonical transcript for MSTO1...
# Fetching canonical transcript for OLFML2B...
# Fetching canonical transcript for GDF3...
# Fetching canonical transcript for KIAA0586...
# Fetching canonical transcript for ABCA4...
# Fetching canonical transcript for HSF4...
# Fetching canonical transcript for CYP27A1...
# Fetching canonical transcript for ADAR...
# Fetching canonical transcript for UPB1...
# Fetching canonical transcript for RP1L1...
# Fetching canonical transcript for MAP2K2...
# Fetching canonical transcript for TGFBR2...
# Fetching canonical transcript for TGFB2...
# Fetching canonical transcript for KCNQ1...
# Fetching canonical transcript for KCNC1...
# Fetching canonical transcript for L2HGDH...
# Fetching canonical transcript for VPS33B...
# Fetching canonical transcript for CTCF...
# Fetching canonical transcript for ELANE...
# Fetching canonical transcript for BCKDHA...
# Fetching canonical transcript for PRSS56...
# Fetching canonical transcript for CTNNB1...
# Fetching canonical transcript for KCNH2...
# Fetching canonical transcript for GRIN1...
# Fetching canonical transcript for IFT43...
# Fetching canonical transcript for CNPY3-GNMT...
# Request failed for /lookup/symbol/homo_sapiens/CNPY3-GNMT: 400 Bad Request
# Fetching canonical transcript for CRYGA...
# Fetching canonical transcript for ROS1...
# Fetching canonical transcript for ANKS6...
# Fetching canonical transcript for LDLR...
# Fetching canonical transcript for PIGH...
# Fetching canonical transcript for STRA6...
# Fetching canonical transcript for ABCB6...
# Fetching canonical transcript for LOC102724788...
# Request failed for /lookup/symbol/homo_sapiens/LOC102724788: 400 Bad Request
# Fetching canonical transcript for PEPD...
# Fetching canonical transcript for RYR1...
# Fetching canonical transcript for UGT1A1...
# Fetching canonical transcript for AGL...
# Fetching canonical transcript for LBR...
# Fetching canonical transcript for CD3G...
# Fetching canonical transcript for KMT2D...
# Fetching canonical transcript for CEP290...
# Fetching canonical transcript for BRCA2...
# Fetching canonical transcript for CREBBP...
# Fetching canonical transcript for PAFAH1B1...
# Fetching canonical transcript for KMT2B...
# Fetching canonical transcript for BAX...
# Fetching canonical transcript for MSH6...
# Fetching canonical transcript for SLC4A11...
# Fetching canonical transcript for LZTR1...
# Fetching canonical transcript for DEPDC5...
# Fetching canonical transcript for SDHA...
# Fetching canonical transcript for APC...
# Fetching canonical transcript for HSD17B3...
# Fetching canonical transcript for PCDH19...
# Fetching canonical transcript for FUT2...
# Fetching canonical transcript for NCF4...
# Fetching canonical transcript for EPHB2...
# Fetching canonical transcript for CFAP300...
# Fetching canonical transcript for MAP2K1...
# Fetching canonical transcript for NDUFV1...
# Fetching canonical transcript for AGT...
# Fetching canonical transcript for CHST8...
# Fetching canonical transcript for MTHFR...
# Fetching canonical transcript for EBF3...
# Fetching canonical transcript for LPL...
# Fetching canonical transcript for LINGO1...
# Fetching canonical transcript for CHEK2...
# Fetching canonical transcript for SGO1...
# Fetching canonical transcript for NOTCH1...
# Fetching canonical transcript for ABCC6...
# Fetching canonical transcript for MCM8...
# Fetching canonical transcript for CACNA1A...
# Fetching canonical transcript for TMPRSS3...
# Fetching canonical transcript for SLC26A2...
# Fetching canonical transcript for KLK4...
# Fetching canonical transcript for GYG1...
# Fetching canonical transcript for GALC...
# Fetching canonical transcript for MUTYH...
# Fetching canonical transcript for PPOX...
# Fetching canonical transcript for ATP7B...
# Fetching canonical transcript for SLC26A4...
# Fetching canonical transcript for TYR...
# Fetching canonical transcript for ERBB2...
# Fetching canonical transcript for GYS2...
# Fetching canonical transcript for DUOX2...
# Fetching canonical transcript for BRIP1...
# Fetching canonical transcript for COQ2...
# Fetching canonical transcript for DNAH5...
# Fetching canonical transcript for ALDH1A3...
# Fetching canonical transcript for FGFR3...
# Fetching canonical transcript for TSC1...
# Fetching canonical transcript for FLG...
# Fetching canonical transcript for KRT83...
# Fetching canonical transcript for NPHS1...
# Fetching canonical transcript for SPG7...
# Fetching canonical transcript for KIF21A...
# Fetching canonical transcript for BRCA1...
# Fetching canonical transcript for F9...
# Fetching canonical transcript for HSD17B4...
# Fetching canonical transcript for FOXRED1...
# Fetching canonical transcript for RHOA...
# Fetching canonical transcript for TYRP1...
# Fetching canonical transcript for PAH...
# Fetching canonical transcript for ESR1...
# Fetching canonical transcript for NUBPL...
# Fetching canonical transcript for RAD51...
# Fetching canonical transcript for ADNP...
# Fetching canonical transcript for BRAF...
# Fetching canonical transcript for CYP11A1...
# Fetching canonical transcript for SPG11...
# Fetching canonical transcript for GALT...
# Fetching canonical transcript for POMT2...
# Fetching canonical transcript for LRP5...
# Fetching canonical transcript for ERCC6...
# Fetching canonical transcript for OTOG...
# Fetching canonical transcript for THOC6...
# Fetching canonical transcript for DNMT3A...
# Fetching canonical transcript for HUWE1...
# Fetching canonical transcript for DHCR7...
# Fetching canonical transcript for TCF4...
# Fetching canonical transcript for LMOD3...
# Fetching canonical transcript for G6PD...
# Fetching canonical transcript for MAGED2...
# Fetching canonical transcript for GCGR...
# Fetching canonical transcript for PRKN...
# Fetching canonical transcript for VWA8...
# Fetching canonical transcript for GMPPB...
# Fetching canonical transcript for TBXAS1...
# Fetching canonical transcript for PPT1...
# Fetching canonical transcript for SLC19A3...
# Fetching canonical transcript for MLH1...
# Fetching canonical transcript for TF...
# Fetching canonical transcript for FOXC1...
# Fetching canonical transcript for GUCA1A...
# Fetching canonical transcript for FOXP4...
# Fetching canonical transcript for ALDOB...
# Fetching canonical transcript for HRAS...
# Fetching canonical transcript for CEP83...
# Fetching canonical transcript for PTGIS...
# Fetching canonical transcript for BTK...
# Fetching canonical transcript for F7...
# Fetching canonical transcript for DNAH9...
# Fetching canonical transcript for SLC4A1...
# Fetching canonical transcript for ALPL...
# Fetching canonical transcript for SIN3A...
# Fetching canonical transcript for SMN1...
# Fetching canonical transcript for SURF1...
# Fetching canonical transcript for TTN...
# Fetching canonical transcript for CBS...
# Fetching canonical transcript for CHD7...
# Fetching canonical transcript for LMNA...
# Fetching canonical transcript for C7...
# Fetching canonical transcript for C6...
# Fetching canonical transcript for COL7A1...
# Fetching canonical transcript for PEX1...
# Fetching canonical transcript for OGG1...
# Fetching canonical transcript for FIG4...
# Fetching canonical transcript for BRAT1...
# Fetching canonical transcript for COL4A5...
# Fetching canonical transcript for STAT5B...
# Fetching canonical transcript for NLRP7...
# Fetching canonical transcript for MSH2...
# Fetching canonical transcript for GNAS...
# Fetching canonical transcript for PDE6A...
# Fetching canonical transcript for SERAC1...
# Fetching canonical transcript for ZFHX3...
# Fetching canonical transcript for MYMK...
# Fetching canonical transcript for MYO9A...
# Fetching canonical transcript for MC2R...
# Fetching canonical transcript for KIT...
# Fetching canonical transcript for HOGA1...
# Fetching canonical transcript for NF1...
# Fetching canonical transcript for ERMAP...
# Fetching canonical transcript for NSD1...
# Fetching canonical transcript for ITGB2...
# Fetching canonical transcript for COL4A3...
# Fetching canonical transcript for BCKDHB...
# Fetching canonical transcript for FAM98C...
# Fetching canonical transcript for PADI3...
# Fetching canonical transcript for BSND...
# Fetching canonical transcript for NAGLU...
# Fetching canonical transcript for FUT1...
# Fetching canonical transcript for COL1A2...
# Fetching canonical transcript for EVC2...
# Fetching canonical transcript for EARS2...
# Fetching canonical transcript for BBS12...
# Fetching canonical transcript for EXOSC3...
# Fetching canonical transcript for WAC...
# Fetching canonical transcript for MYO7A...
# Fetching canonical transcript for MKS1...
# Fetching canonical transcript for INSL3...
# Fetching canonical transcript for DOK7...
# Fetching canonical transcript for SF3B4...
# Fetching canonical transcript for NCSTN...
# Fetching canonical transcript for ABCA12...
# Fetching canonical transcript for GLB1...
# Fetching canonical transcript for AHI1...
# Fetching canonical transcript for ARID1B...
# Fetching canonical transcript for HPS1...
# Fetching canonical transcript for NKX6-2...
# Fetching canonical transcript for VSX2...
# Fetching canonical transcript for ZNF469...
# Fetching canonical transcript for FANCA...
# Fetching canonical transcript for DNAH11...
# Fetching canonical transcript for OTC...
# Fetching canonical transcript for MRE11...
# Fetching canonical transcript for PDGFRA...
# Fetching canonical transcript for WAS...
# Fetching canonical transcript for PMPCA...
# Fetching canonical transcript for GNE...
# Fetching canonical transcript for AICDA...
# Fetching canonical transcript for CYP27B1...
# Fetching canonical transcript for COL6A2...
# Fetching canonical transcript for MFN2...
# Fetching canonical transcript for POGZ...
# Fetching canonical transcript for MYBPC3...
# Fetching canonical transcript for POU1F1...
# Fetching canonical transcript for STAR...
# Fetching canonical transcript for RYR2...
# Fetching canonical transcript for EGFR...
# Fetching canonical transcript for WASHC5...
# Fetching canonical transcript for CAPN3...
# Fetching canonical transcript for TBXA2R...
# Fetching canonical transcript for DYNC2LI1...
# Fetching canonical transcript for SLC7A14...
# Fetching canonical transcript for MYH7...
# Fetching canonical transcript for IDS...
# Fetching canonical transcript for STK11...
# Fetching canonical transcript for DCHS1...
# Fetching canonical transcript for LYRM7...
# Fetching canonical transcript for B3GALT6...
# Fetching canonical transcript for USH2A...
# Fetching canonical transcript for ABCC8...
# Fetching canonical transcript for ERBB3...
# Fetching canonical transcript for TMPRSS6...
# Fetching canonical transcript for TPP1...
# Fetching canonical transcript for MMUT...
# Fetching canonical transcript for TOR1A...
# Fetching canonical transcript for MEN1...
# Fetching canonical transcript for BTD...
# Fetching canonical transcript for DHTKD1...
# Fetching canonical transcript for JAG1...
# Fetching canonical transcript for DMD...
# Fetching canonical transcript for TBX5...
# Fetching canonical transcript for PUS1...
# Fetching canonical transcript for S1PR2...
# Fetching canonical transcript for COMP...
# Fetching canonical transcript for DHX30...
# Fetching canonical transcript for F8...
# Fetching canonical transcript for MMAB...
# Fetching canonical transcript for SPAST...
# Fetching canonical transcript for HPCA...
# Fetching canonical transcript for CHRNG...
# Fetching canonical transcript for TWNK...
# Fetching canonical transcript for LRP4...
# Fetching canonical transcript for NAGA...
# Fetching canonical transcript for PTCH1...
# Fetching canonical transcript for LAMC2...
# Fetching canonical transcript for DYSF...
# Fetching canonical transcript for GDAP1...
# Fetching canonical transcript for CUBN...
# Fetching canonical transcript for NANOS1...
# Fetching canonical transcript for FAM111A...
# Fetching canonical transcript for SDHB...
# Fetching canonical transcript for PRNP...
# Fetching canonical transcript for GLRX5...
# Fetching canonical transcript for RAB7A...
# Fetching canonical transcript for KIF5A...
# Fetching canonical transcript for AIPL1...
# Fetching canonical transcript for SCN1A...
# Fetching canonical transcript for UMOD...
# Fetching canonical transcript for NBN...
# Fetching canonical transcript for SZT2...
# Fetching canonical transcript for DHCR24...
# Fetching canonical transcript for TNNT2...
# Fetching canonical transcript for ACTG2...
# Fetching canonical transcript for CTNNA2...
# Fetching canonical transcript for NEB...
# Fetching canonical transcript for IFIH1...
# Fetching canonical transcript for SCN2A...
# Fetching canonical transcript for ABCB11...
# Fetching canonical transcript for AGA...
# Fetching canonical transcript for SLC45A2...
# Fetching canonical transcript for PIK3R1...
# Fetching canonical transcript for NDST1...
# Fetching canonical transcript for DDC...
# Fetching canonical transcript for CLCN1...
# Fetching canonical transcript for GATA4...
# Fetching canonical transcript for SPTAN1...
# Fetching canonical transcript for CDH23...
# Fetching canonical transcript for IGHMBP2...
# Fetching canonical transcript for COL2A1...
# Fetching canonical transcript for RPGRIP1...
# Fetching canonical transcript for PKD1...
# Fetching canonical transcript for ACE...
# Fetching canonical transcript for GREB1L...
# Fetching canonical transcript for PLCB4...
# Fetching canonical transcript for SEC23B...
# Fetching canonical transcript for GPR143...
# Fetching canonical transcript for TAZ...
# Request failed for /lookup/symbol/homo_sapiens/TAZ: 400 Bad Request
# Fetching canonical transcript for POLR3A...
# Fetching canonical transcript for OTOF...
# Fetching canonical transcript for GCH1...
# Fetching canonical transcript for TSHR...
# Fetching canonical transcript for RECQL4...
# Fetching canonical transcript for TENM4...
# Fetching canonical transcript for GNPTG...
# Fetching canonical transcript for SYNGAP1...
# Fetching canonical transcript for F11...
# Fetching canonical transcript for TMC1...
# Fetching canonical transcript for PALB2...
# Fetching canonical transcript for AGRN...
# Fetching canonical transcript for CRB1...
# Fetching canonical transcript for ROM1...
# Fetching canonical transcript for CPOX...
# Fetching canonical transcript for DDB2...
# Fetching canonical transcript for SMPD1...
# Fetching canonical transcript for AMT...
# Fetching canonical transcript for RNF43...
# Fetching canonical transcript for FLCN...
# Fetching canonical transcript for SCN5A...
# Fetching canonical transcript for CNTN2...
# Fetching canonical transcript for CFHR5...
# Fetching canonical transcript for KLHL3...
# Fetching canonical transcript for SCARB2...
# Fetching canonical transcript for PDGFRB...
# Fetching canonical transcript for OCA2...
# Fetching canonical transcript for GJB4...
# Fetching canonical transcript for SLURP1...
# Fetching canonical transcript for AASS...
# Fetching canonical transcript for PHEX...
# Fetching canonical transcript for GAMT...
# Fetching canonical transcript for LIG4...
# Fetching canonical transcript for DYNC1H1...
# Fetching canonical transcript for TBC1D24...
# Fetching canonical transcript for GRIP1...
# Fetching canonical transcript for MLC1...
# Fetching canonical transcript for NCF1...
# Fetching canonical transcript for KCNJ2...
# Fetching canonical transcript for PDE11A...
# Fetching canonical transcript for F13A1...
# Fetching canonical transcript for PIEZO2...
# Fetching canonical transcript for KCNJ11...
# Fetching canonical transcript for AGBL1...
# Fetching canonical transcript for ACADVL...
# Fetching canonical transcript for GFAP...
# Fetching canonical transcript for ACAD9...
# Fetching canonical transcript for KCNJ1...
# Fetching canonical transcript for PAX3...
# Fetching canonical transcript for SAA1...
# Fetching canonical transcript for SACS...
# Fetching canonical transcript for POMGNT1...
# Fetching canonical transcript for CYP17A1...
# Fetching canonical transcript for H3F3A...
# Request failed for /lookup/symbol/homo_sapiens/H3F3A: 400 Bad Request
# Fetching canonical transcript for PROC...
# Fetching canonical transcript for TGM1...
# Fetching canonical transcript for SBDS...
# Fetching canonical transcript for ASPM...
# Fetching canonical transcript for IDH1...
# Fetching canonical transcript for RRAS2...
# Fetching canonical transcript for ROBO4...
# Fetching canonical transcript for COL9A1...
# Fetching canonical transcript for PITX2...
# Fetching canonical transcript for ALG6...
# Fetching canonical transcript for CSF1R...
# Fetching canonical transcript for ERF...
# Fetching canonical transcript for CDKL5...
# Fetching canonical transcript for ADA2...
# Fetching canonical transcript for NIPBL...
# Fetching canonical transcript for SOHLH1...
# Fetching canonical transcript for TSEN2...
# Fetching canonical transcript for CD19...
# Fetching canonical transcript for TJP2...
# Fetching canonical transcript for SLC36A2...
# Fetching canonical transcript for RPGRIP1L...
# Fetching canonical transcript for RAB3GAP2...
# Fetching canonical transcript for RASA1...
# Fetching canonical transcript for GLRA1...
# Fetching canonical transcript for ANKRD11...
# Fetching canonical transcript for CA5A...
# Fetching canonical transcript for CAMK2A...
# Fetching canonical transcript for CPT2...
# Fetching canonical transcript for MYT1L...
# Fetching canonical transcript for ROBO3...
# Fetching canonical transcript for PTPN11...
# Fetching canonical transcript for DCAF6...
# Fetching canonical transcript for PDE6H...
# Fetching canonical transcript for MED12...
# Fetching canonical transcript for CASP10...
# Fetching canonical transcript for SGSH...
# Fetching canonical transcript for ABCA7...
# Fetching canonical transcript for ELMOD3...
# Fetching canonical transcript for FANCD2...
# Fetching canonical transcript for MYO15A...
# Fetching canonical transcript for GLI2...
# Fetching canonical transcript for BRPF1...
# Fetching canonical transcript for ABCG8...
# Fetching canonical transcript for NOTCH3...
# Fetching canonical transcript for KMT2A...
# Fetching canonical transcript for TUBB3...
# Fetching canonical transcript for SLC17A9...
# Fetching canonical transcript for RNASEH2B...
# Fetching canonical transcript for DYRK1A...
# Fetching canonical transcript for TTLL5...
# Fetching canonical transcript for DVL1...
# Fetching canonical transcript for INCENP...
# Fetching canonical transcript for CRX...
# Fetching canonical transcript for GJB3...
# Fetching canonical transcript for VHL...
# Fetching canonical transcript for ASL...
# Fetching canonical transcript for ASNS...
# Fetching canonical transcript for IL12RB1...
# Fetching canonical transcript for ZEB1...
# Fetching canonical transcript for ETFA...
# Fetching canonical transcript for GJA1...
# Fetching canonical transcript for ARID1A...
# Fetching canonical transcript for DARS2...
# Fetching canonical transcript for XPC...
# Fetching canonical transcript for CHM...
# Fetching canonical transcript for MID2...
# Fetching canonical transcript for ASXL2...
# Fetching canonical transcript for DYM...
# Fetching canonical transcript for PSEN2...
# Fetching canonical transcript for KMT2C...
# Fetching canonical transcript for AFG3L2...
# Fetching canonical transcript for FA2H...
# Fetching canonical transcript for ACADM...
# Fetching canonical transcript for PINK1...
# Fetching canonical transcript for SLC25A15...
# Fetching canonical transcript for PPP2R1A...
# Fetching canonical transcript for DPYS...
# Fetching canonical transcript for MRPS2...
# Fetching canonical transcript for AVPR2...
# Fetching canonical transcript for STIM1...
# Fetching canonical transcript for STAT3...
# Fetching canonical transcript for PIGG...
# Fetching canonical transcript for DNAH1...
# Fetching canonical transcript for ARX...
# Fetching canonical transcript for HJV...
# Fetching canonical transcript for ETHE1...
# Fetching canonical transcript for ZEB2...
# Fetching canonical transcript for LAMA2...
# Fetching canonical transcript for GLDC...
# Fetching canonical transcript for CLCN5...
# Fetching canonical transcript for CCDC103...
# Fetching canonical transcript for ADAMTSL4...
# Fetching canonical transcript for LRRC6...
# Request failed for /lookup/symbol/homo_sapiens/LRRC6: 400 Bad Request
# Fetching canonical transcript for HBD...
# Fetching canonical transcript for EGR2...
# Fetching canonical transcript for GFM1...
# Fetching canonical transcript for ADGRG1...
# Fetching canonical transcript for GNPTAB...
# Fetching canonical transcript for SCO1...
# Fetching canonical transcript for COL1A1...
# Fetching canonical transcript for FGFR2...
# Fetching canonical transcript for KAT6B...
# Fetching canonical transcript for CC2D2A...
# Fetching canonical transcript for AIFM1...
# Fetching canonical transcript for MAPK7...
# Fetching canonical transcript for CYP1B1...
# Fetching canonical transcript for MYOM1...
# Fetching canonical transcript for HNF1A...
# Fetching canonical transcript for ARMC9...
# Fetching canonical transcript for SPART...
# Fetching canonical transcript for KATNB1...
# Fetching canonical transcript for COG4...
# Fetching canonical transcript for ADA...
# Fetching canonical transcript for GHRHR...
# Fetching canonical transcript for RAX2...
# Fetching canonical transcript for SLC25A13...
# Fetching canonical transcript for TGM5...
# Fetching canonical transcript for MIB1...
# Fetching canonical transcript for UROD...
# Fetching canonical transcript for ABCC2...
# Fetching canonical transcript for BARD1...
# Fetching canonical transcript for MSH3...
# Fetching canonical transcript for RAD54B...
# Fetching canonical transcript for VCP...
# Fetching canonical transcript for DNMT3B...
# Fetching canonical transcript for ZNF687...
# Fetching canonical transcript for COL3A1...
# Fetching canonical transcript for FBP1...
# Fetching canonical transcript for RNASEL...
# Fetching canonical transcript for KCNE1...
# Fetching canonical transcript for APOC2...
# Fetching canonical transcript for ARSA...
# Fetching canonical transcript for MEFV...
# Fetching canonical transcript for BMPR1A...
# Fetching canonical transcript for COX15...
# Fetching canonical transcript for IRF6...
# Fetching canonical transcript for COLQ...
# Fetching canonical transcript for PLEC...
# Fetching canonical transcript for ACTA2...
# Fetching canonical transcript for IL10RA...
# Fetching canonical transcript for SP7...
# Fetching canonical transcript for ATP2A1...
# Fetching canonical transcript for INPP5K...
# Fetching canonical transcript for CPLANE1...
# Fetching canonical transcript for SCO2...
# Fetching canonical transcript for BMP15...
# Fetching canonical transcript for GCDH...
# Fetching canonical transcript for SH3PXD2B...
# Fetching canonical transcript for LOXHD1...
# Fetching canonical transcript for PQBP1...
# Fetching canonical transcript for PLA2G6...
# Fetching canonical transcript for ACTA1...
# Fetching canonical transcript for PEX6...
# Fetching canonical transcript for CACNA1F...
# Fetching canonical transcript for SOS1...
# Fetching canonical transcript for RAB3GAP1...
# Fetching canonical transcript for PKD2...
# Fetching canonical transcript for RAD50...
# Fetching canonical transcript for CSPP1...
# Fetching canonical transcript for CYP11B1...
# Fetching canonical transcript for ACADS...
# Fetching canonical transcript for CDH1...
# Fetching canonical transcript for CFAP410...
# Fetching canonical transcript for TRIP12...
# Fetching canonical transcript for PNKP...
# Fetching canonical transcript for SGCA...
# Fetching canonical transcript for SELENON...
# Fetching canonical transcript for ATP1A2...
# Fetching canonical transcript for KCNQ2...
# Fetching canonical transcript for GCKR...
# Fetching canonical transcript for FAH...
# Fetching canonical transcript for DSP...
# Fetching canonical transcript for CTSF...
# Fetching canonical transcript for NALCN...
# Fetching canonical transcript for NUP93...
# Fetching canonical transcript for KLHL10...
# Fetching canonical transcript for FKTN...
# Fetching canonical transcript for HBA2...
# Fetching canonical transcript for AIMP2...
# Fetching canonical transcript for SYNE1...
# Fetching canonical transcript for RSPH4A...
# Fetching canonical transcript for TBL1XR1...
# Fetching canonical transcript for GNAO1...
# Fetching canonical transcript for RPGR...
# Fetching canonical transcript for CNGA3...
# Fetching canonical transcript for GRM6...
# Fetching canonical transcript for MSX1...
# Fetching canonical transcript for EXOSC9...
# Fetching canonical transcript for SUN5...
# Fetching canonical transcript for ZBTB18...
# Fetching canonical transcript for ACTB...
# Fetching canonical transcript for HNF1B...
# Fetching canonical transcript for NDUFS8...
# Fetching canonical transcript for ALMS1...
# Fetching canonical transcript for NDUFS3...
# Fetching canonical transcript for PRCD...
# Fetching canonical transcript for CERKL...
# Fetching canonical transcript for KCNK17...
# Fetching canonical transcript for GAA...
# Fetching canonical transcript for GNRHR...
# Fetching canonical transcript for AK2...
# Fetching canonical transcript for POGLUT1...
# Fetching canonical transcript for CERT1...
# Fetching canonical transcript for MYC...
# Fetching canonical transcript for TRAF3IP1...
# Fetching canonical transcript for PSEN1...
# Fetching canonical transcript for PAX6...
# Fetching canonical transcript for THRB...
# Fetching canonical transcript for PDE6C...
# Fetching canonical transcript for CEP152...
# Fetching canonical transcript for FGG...
# Fetching canonical transcript for GCM2...
# Fetching canonical transcript for POLG...
# Fetching canonical transcript for SMARCA2...
# Fetching canonical transcript for CENPF...
# Fetching canonical transcript for MRPS7...
# Fetching canonical transcript for ACVR1...
# Fetching canonical transcript for SECISBP2...
# Fetching canonical transcript for MLYCD...
# Fetching canonical transcript for SGCB...
# Fetching canonical transcript for FTL...
# Fetching canonical transcript for TTR...
# Fetching canonical transcript for DNM2...
# Fetching canonical transcript for TYMP...
# Fetching canonical transcript for POLH...
# Fetching canonical transcript for APTX...
# Fetching canonical transcript for YWHAG...
# Fetching canonical transcript for LIAS...
# Fetching canonical transcript for ERCC4...
# Fetching canonical transcript for RPUSD3...
# Fetching canonical transcript for ITGB3...
# Fetching canonical transcript for FZD4...
# Fetching canonical transcript for DSG2...
# Fetching canonical transcript for SMAD3...
# Fetching canonical transcript for OTOGL...
# Fetching canonical transcript for SPOP...
# Fetching canonical transcript for NPC2...
# Fetching canonical transcript for DDX3X...
# Fetching canonical transcript for ADPRHL2...
# Request failed for /lookup/symbol/homo_sapiens/ADPRHL2: 400 Bad Request
# Fetching canonical transcript for PYGM...
# Fetching canonical transcript for DNAI1...
# Fetching canonical transcript for ALK...
# Fetching canonical transcript for SPTBN4...
# Fetching canonical transcript for SRD5A3...
# Fetching canonical transcript for RSPO4...
# Fetching canonical transcript for SPATA5...
# Request failed for /lookup/symbol/homo_sapiens/SPATA5: 400 Bad Request
# Fetching canonical transcript for ATP6V0A4...
# Fetching canonical transcript for DYNC2H1...
# Fetching canonical transcript for NTF4...
# Fetching canonical transcript for AQP1...
# Fetching canonical transcript for KAT6A...
# Fetching canonical transcript for BBS10...
# Fetching canonical transcript for KANSL1...
# Fetching canonical transcript for SLC12A1...
# Fetching canonical transcript for NECTIN3...
# Fetching canonical transcript for TPR...
# Fetching canonical transcript for ALDH6A1...
# Fetching canonical transcript for AARS2...
# Fetching canonical transcript for BLM...
# Fetching canonical transcript for FCSK...
# Fetching canonical transcript for NPHP3...
# Fetching canonical transcript for ASB10...
# Fetching canonical transcript for PCCB...
# Fetching canonical transcript for CUL7...
# Fetching canonical transcript for CARS2...
# Fetching canonical transcript for ACO2...
# Fetching canonical transcript for IL17RD...
# Fetching canonical transcript for MRPS22...
# Fetching canonical transcript for FSHR...
# Fetching canonical transcript for LRP2...
# Fetching canonical transcript for SF3B1...
# Fetching canonical transcript for GNAQ...
# Fetching canonical transcript for CD36...
# Fetching canonical transcript for RLBP1...
# Fetching canonical transcript for ITGB6...
# Fetching canonical transcript for KRT81...
# Fetching canonical transcript for TMIE...
# Fetching canonical transcript for RAF1...
# Fetching canonical transcript for GPC6...
# Fetching canonical transcript for ANO5...
# Fetching canonical transcript for DSTYK...
# Fetching canonical transcript for C8B...
# Fetching canonical transcript for EDA...
# Fetching canonical transcript for MKKS...
# Fetching canonical transcript for FANCC...
# Fetching canonical transcript for SH3TC2...
# Fetching canonical transcript for RNASEH2A...
# Fetching canonical transcript for PRF1...
# Fetching canonical transcript for FLT3...
# Fetching canonical transcript for HADHB...
# Fetching canonical transcript for PIGO...
# Fetching canonical transcript for MKRN3...
# Fetching canonical transcript for SMARCB1...
# Fetching canonical transcript for ABCD1...
# Fetching canonical transcript for SOX17...
# Fetching canonical transcript for MFRP...
# Fetching canonical transcript for ASS1...
# Fetching canonical transcript for USB1...
# Fetching canonical transcript for DARS...
# Request failed for /lookup/symbol/homo_sapiens/DARS: 400 Bad Request
# Fetching canonical transcript for CANT1...
# Fetching canonical transcript for CYP24A1...
# Fetching canonical transcript for EXT1...
# Fetching canonical transcript for CYP7B1...
# Fetching canonical transcript for MCCC2...
# Fetching canonical transcript for SCN4A...
# Fetching canonical transcript for SBF1...
# Fetching canonical transcript for TUBB2A...
# Fetching canonical transcript for ADAMTS13...
# Fetching canonical transcript for MTSS2...
# Fetching canonical transcript for RAD51D...
# Fetching canonical transcript for ALOXE3...
# Fetching canonical transcript for MPO...
# Fetching canonical transcript for KCNJ13...
# Fetching canonical transcript for MPV17...
# Fetching canonical transcript for ACAD8...
# Fetching canonical transcript for AHSG...
# Fetching canonical transcript for EDAR...
# Fetching canonical transcript for SLC3A1...
# Fetching canonical transcript for COL4A4...
# Fetching canonical transcript for SLC34A1...
# Fetching canonical transcript for CA12...
# Fetching canonical transcript for IMPDH1...
# Fetching canonical transcript for GUCY2C...
# Fetching canonical transcript for IFT80...
# Fetching canonical transcript for TSFM...
# Fetching canonical transcript for PLCG2...
# Fetching canonical transcript for CHD3...
# Fetching canonical transcript for ASXL1...
# Fetching canonical transcript for VPS45...
# Fetching canonical transcript for PREPL...
# Fetching canonical transcript for SRP72...
# Fetching canonical transcript for SLC6A3...
# Fetching canonical transcript for LITAF...
# Fetching canonical transcript for DHX38...
# Fetching canonical transcript for HAMP...
# Fetching canonical transcript for RLIM...
# Fetching canonical transcript for OCRL...
# Fetching canonical transcript for DGUOK...
# Fetching canonical transcript for LIPE...
# Fetching canonical transcript for OAT...
# Fetching canonical transcript for RNF135...
# Fetching canonical transcript for ANTXR2...
# Fetching canonical transcript for EIF2B4...
# Fetching canonical transcript for USH1C...
# Fetching canonical transcript for DHH...
# Fetching canonical transcript for PARN...
# Fetching canonical transcript for FKBP10...
# Fetching canonical transcript for TNNI3...
# Fetching canonical transcript for ALG1...
# Fetching canonical transcript for MEF2A...
# Fetching canonical transcript for TMEM231...
# Fetching canonical transcript for WRAP53...
# Fetching canonical transcript for MYL3...
# Fetching canonical transcript for ACTC1...
# Fetching canonical transcript for POMT1...
# Fetching canonical transcript for CLDN14...
# Fetching canonical transcript for SLC6A19...
# Fetching canonical transcript for MYH2...
# Fetching canonical transcript for DKC1...
# Fetching canonical transcript for RNF170...
# Fetching canonical transcript for GLA...
# Fetching canonical transcript for GBA...
# Request failed for /lookup/symbol/homo_sapiens/GBA: 400 Bad Request
# Fetching canonical transcript for PCCA...
# Fetching canonical transcript for RARS2...
# Fetching canonical transcript for PHKG2...
# Fetching canonical transcript for NEK1...
# Fetching canonical transcript for LPAR6...
# Fetching canonical transcript for RORA...
# Fetching canonical transcript for COL18A1...
# Fetching canonical transcript for IQCE...
# Fetching canonical transcript for UNC13D...
# Fetching canonical transcript for MTO1...
# Fetching canonical transcript for PEX10...
# Fetching canonical transcript for NOBOX...
# Fetching canonical transcript for SLC26A8...
# Fetching canonical transcript for ATP6V1B1...
# Fetching canonical transcript for AP4B1...
# Fetching canonical transcript for KCTD7...
# Fetching canonical transcript for SLC34A3...
# Fetching canonical transcript for NBAS...
# Fetching canonical transcript for RP9...
# Fetching canonical transcript for MMP9...
# Fetching canonical transcript for RHD...
# Fetching canonical transcript for TRDN...
# Fetching canonical transcript for TH...
# Fetching canonical transcript for CPAMD8...
# Fetching canonical transcript for SERPINA1...
# Fetching canonical transcript for CIITA...
# Fetching canonical transcript for RIN2...
# Fetching canonical transcript for GLYCTK...
# Fetching canonical transcript for AHDC1...
# Fetching canonical transcript for CSRP3...
# Fetching canonical transcript for SUGCT...
# Fetching canonical transcript for ERBB4...
# Fetching canonical transcript for SLC2A2...
# Fetching canonical transcript for FLT4...
# Fetching canonical transcript for COL5A1...
# Fetching canonical transcript for RAG1...
# Fetching canonical transcript for EIF2AK4...
# Fetching canonical transcript for BBS4...
# Fetching canonical transcript for RUNX1...
# Fetching canonical transcript for ATP8A2...
# Fetching canonical transcript for GLE1...
# Fetching canonical transcript for PEX16...
# Fetching canonical transcript for TCF12...
# Fetching canonical transcript for BMPR1B...
# Fetching canonical transcript for GCK...
# Fetching canonical transcript for VPS33A...
# Fetching canonical transcript for IKZF1...
# Fetching canonical transcript for PROM1...
# Fetching canonical transcript for PCDHB4...
# Fetching canonical transcript for CYP4F22...
# Fetching canonical transcript for DPAGT1...
# Fetching canonical transcript for FOXP1...
# Fetching canonical transcript for BPGM...
# Fetching canonical transcript for B4GALNT1...
# Fetching canonical transcript for ATL1...
# Fetching canonical transcript for ROGDI...
# Fetching canonical transcript for RS1...
# Fetching canonical transcript for MSX2...
# Fetching canonical transcript for DNAAF1...
# Fetching canonical transcript for LPIN2...
# Fetching canonical transcript for MPZ...
# Fetching canonical transcript for XPO1...
# Fetching canonical transcript for EIF2B5...
# Fetching canonical transcript for FBXL4...
# Fetching canonical transcript for RFX6...
# Fetching canonical transcript for CNGB3...
# Fetching canonical transcript for FGF8...
# Fetching canonical transcript for CDK10...
# Fetching canonical transcript for TK2...
# Fetching canonical transcript for VDR...
# Fetching canonical transcript for ECHS1...
# Fetching canonical transcript for CHAT...
# Fetching canonical transcript for BIVM-ERCC5...
# Fetching canonical transcript for FOXG1...
# Fetching canonical transcript for CLN3...
# Fetching canonical transcript for AXIN2...
# Fetching canonical transcript for TIMM50...
# Fetching canonical transcript for AMER1...
# Fetching canonical transcript for SLC2A1...
# Fetching canonical transcript for AAAS...
# Fetching canonical transcript for RHO...
# Fetching canonical transcript for TRPM1...
# Fetching canonical transcript for WDR35...
# Fetching canonical transcript for PAX8...
# Fetching canonical transcript for PPARG...
# Fetching canonical transcript for C5...
# Fetching canonical transcript for ITGB4...
# Fetching canonical transcript for APOC3...
# Fetching canonical transcript for AP4S1...
# Fetching canonical transcript for TYK2...
# Fetching canonical transcript for NR5A1...
# Fetching canonical transcript for TRIM32...
# Fetching canonical transcript for MYH9...
# Fetching canonical transcript for SLC29A3...
# Fetching canonical transcript for CD207...
# Fetching canonical transcript for DSC2...
# Fetching canonical transcript for IYD...
# Fetching canonical transcript for PTS...
# Fetching canonical transcript for SERPINF2...
# Fetching canonical transcript for PCYT1A...
# Fetching canonical transcript for HACE1...
# Fetching canonical transcript for SLC12A6...
# Fetching canonical transcript for TMEM240...
# Fetching canonical transcript for STXBP1...
# Fetching canonical transcript for LSS...
# Fetching canonical transcript for TNXB...
# Fetching canonical transcript for AK1...
# Fetching canonical transcript for MPI...
# Fetching canonical transcript for EP300...
# Fetching canonical transcript for CHRNE...
# Fetching canonical transcript for CYB5R3...
# Fetching canonical transcript for CACNA1C...
# Fetching canonical transcript for MVK...
# Fetching canonical transcript for OBSL1...
# Fetching canonical transcript for XRCC4...
# Fetching canonical transcript for HBA1...
# Fetching canonical transcript for DDHD2...
# Fetching canonical transcript for WEE2...
# Fetching canonical transcript for TTC37...
# Request failed for /lookup/symbol/homo_sapiens/TTC37: 400 Bad Request
# Fetching canonical transcript for CNGB1...
# Fetching canonical transcript for LAMA3...
# Fetching canonical transcript for MAT1A...
# Fetching canonical transcript for MRI1...
# Fetching canonical transcript for TGFBI...
# Fetching canonical transcript for MSRB3...
# Fetching canonical transcript for APOA1...
# Fetching canonical transcript for KCNQ3...
# Fetching canonical transcript for MAPK1...
# Fetching canonical transcript for P2RY12...
# Fetching canonical transcript for TREX1...
# Fetching canonical transcript for PIGW...
# Fetching canonical transcript for STXBP2...
# Fetching canonical transcript for PHYKPL...
# Fetching canonical transcript for MTTP...
# Fetching canonical transcript for RNASEH2C...
# Fetching canonical transcript for RTEL1...
# Fetching canonical transcript for CPT1A...
# Fetching canonical transcript for PIK3R2...
# Fetching canonical transcript for CASQ2...
# Fetching canonical transcript for PPP1CB...
# Fetching canonical transcript for HGD...
# Fetching canonical transcript for ALDH18A1...
# Fetching canonical transcript for TMEM67...
# Fetching canonical transcript for SNAP29...
# Fetching canonical transcript for PROKR2...
# Fetching canonical transcript for BEST1...
# Fetching canonical transcript for CBL...
# Fetching canonical transcript for CRYBB1...
# Fetching canonical transcript for CARD14...
# Fetching canonical transcript for CHRND...
# Fetching canonical transcript for HGSNAT...
# Fetching canonical transcript for SMC1A...
# Fetching canonical transcript for IARS...
# Request failed for /lookup/symbol/homo_sapiens/IARS: 400 Bad Request
# Fetching canonical transcript for CNNM4...
# Fetching canonical transcript for CACNB2...
# Fetching canonical transcript for PUF60...
# Fetching canonical transcript for EEF1A2...
# Fetching canonical transcript for SDR9C7...
# Fetching canonical transcript for LTBP2...
# Fetching canonical transcript for RDH5...
# Fetching canonical transcript for TBCE...
# Fetching canonical transcript for PCDH15...
# Fetching canonical transcript for FMO3...
# Fetching canonical transcript for MYOC...
# Fetching canonical transcript for SPARC...
# Fetching canonical transcript for ELP1...
# Fetching canonical transcript for SLC7A9...
# Fetching canonical transcript for ABL1...
# Fetching canonical transcript for RET...
# Fetching canonical transcript for DOCK6...
# Fetching canonical transcript for AR...
# Fetching canonical transcript for TGM6...
# Fetching canonical transcript for HEXB...
# Fetching canonical transcript for STIL...
# Fetching canonical transcript for NDUFS1...
# Fetching canonical transcript for PYROXD1...
# Fetching canonical transcript for AP5Z1...
# Fetching canonical transcript for AGTR1...
# Fetching canonical transcript for THRA...
# Fetching canonical transcript for UCP3...
# Fetching canonical transcript for GRIN2B...
# Fetching canonical transcript for TUBA1A...
# Fetching canonical transcript for NGLY1...
# Fetching canonical transcript for ELMO2...
# Fetching canonical transcript for PMPCB...
# Fetching canonical transcript for LTBP3...
# Fetching canonical transcript for TRMU...
# Fetching canonical transcript for NLRP3...
# Fetching canonical transcript for SAG...
# Fetching canonical transcript for KRT10...
# Fetching canonical transcript for CCNO...
# Fetching canonical transcript for CHD4...
# Fetching canonical transcript for EFTUD2...
# Fetching canonical transcript for ANOS1...
# Fetching canonical transcript for GJB1...
# Fetching canonical transcript for STAG1...
# Fetching canonical transcript for TTBK1...
# Fetching canonical transcript for WDR34...
# Request failed for /lookup/symbol/homo_sapiens/WDR34: 400 Bad Request
# Fetching canonical transcript for PHKA2...
# Fetching canonical transcript for LRBA...
# Fetching canonical transcript for DNAJC21...
# Fetching canonical transcript for PKP2...
# Fetching canonical transcript for ZDHHC9...
# Fetching canonical transcript for LRP6...
# Fetching canonical transcript for TSC2...
# Fetching canonical transcript for F5...
# Fetching canonical transcript for TANGO2...
# Fetching canonical transcript for TAF4B...
# Fetching canonical transcript for P3H1...
# Fetching canonical transcript for MEIS2...
# Fetching canonical transcript for ACSF3...
# Fetching canonical transcript for B9D1...
# Fetching canonical transcript for FLNB...
# Fetching canonical transcript for PRODH...
# Fetching canonical transcript for CDKN1C...
# Fetching canonical transcript for SERPINC1...
# Fetching canonical transcript for SDHAF2...
# Fetching canonical transcript for RNF213...
# Fetching canonical transcript for FANCF...
# Fetching canonical transcript for CNTNAP1...
# Fetching canonical transcript for PYGL...
# Fetching canonical transcript for SLX4...
# Fetching canonical transcript for ROBO2...
# Fetching canonical transcript for AKT1...
# Fetching canonical transcript for FUS...
# Fetching canonical transcript for BRF1...
# Fetching canonical transcript for NR0B1...
# Fetching canonical transcript for NDRG1...
# Fetching canonical transcript for WT1...
# Fetching canonical transcript for ADSL...
# Fetching canonical transcript for U2AF1...
# Fetching canonical transcript for IDH2...
# Fetching canonical transcript for TGIF1...
# Fetching canonical transcript for CASR...
# Fetching canonical transcript for FLNA...
# Fetching canonical transcript for PCSK9...
# Fetching canonical transcript for GRIN2A...
# Fetching canonical transcript for RAC1...
# Fetching canonical transcript for UGT1A8...
# Fetching canonical transcript for MTOR...
# Fetching canonical transcript for BAP1...
# Fetching canonical transcript for MLLT1...
# Fetching canonical transcript for FAN1...
# Fetching canonical transcript for ITPA...
# Fetching canonical transcript for FERMT1...
# Fetching canonical transcript for RAD51C...
# Fetching canonical transcript for COQ4...
# Fetching canonical transcript for TRIP11...
# Fetching canonical transcript for ESCO2...
# Fetching canonical transcript for BCL11A...
# Fetching canonical transcript for MME...
# Fetching canonical transcript for ARAF...
# Fetching canonical transcript for MITF...
# Fetching canonical transcript for CLP1...
# Fetching canonical transcript for PDX1...
# Fetching canonical transcript for PRIMPOL...
# Fetching canonical transcript for UGT1A9...
# Fetching canonical transcript for U2AF1L5...
# Request failed for /lookup/symbol/homo_sapiens/U2AF1L5: 400 Bad Request
# Fetching canonical transcript for SAMHD1...
# Fetching canonical transcript for CCN6...
# Fetching canonical transcript for CHD8...
# Fetching canonical transcript for IL7R...
# Fetching canonical transcript for GALNT14...
# Fetching canonical transcript for CASP8...
# Fetching canonical transcript for TGFBR1...
# Fetching canonical transcript for LRRK2...
# Fetching canonical transcript for PAX2...
# Fetching canonical transcript for GATA6...
# Fetching canonical transcript for TP63...
# Fetching canonical transcript for CDK4...
# Fetching canonical transcript for SMARCA4...
# Fetching canonical transcript for ERCC3...
# Fetching canonical transcript for LIFR...
# Fetching canonical transcript for VRK1...
# Fetching canonical transcript for NDE1...
# Fetching canonical transcript for SOX9...
# Fetching canonical transcript for KDM6A...
# Fetching canonical transcript for FH...
# Fetching canonical transcript for PRDM16...
# Fetching canonical transcript for GNMT...
# Fetching canonical transcript for DOCK8...
# Fetching canonical transcript for FGF3...
# Fetching canonical transcript for EPCAM...
# Fetching canonical transcript for BCOR...
# Fetching canonical transcript for SALL4...
# Fetching canonical transcript for CYP19A1...
# Fetching canonical transcript for DPYD...
# Fetching canonical transcript for PLEKHG2...
# Fetching canonical transcript for EZH2...
# Fetching canonical transcript for SMO...
# Fetching canonical transcript for IFNGR1...
# Fetching canonical transcript for XPA...
# Fetching canonical transcript for GPSM2...
# Fetching canonical transcript for APOB...
# Fetching canonical transcript for ALOX12B...
# Fetching canonical transcript for PMS2...
# Fetching canonical transcript for TUBGCP6...
# Fetching canonical transcript for TEK...
# Fetching canonical transcript for GATA3...
# Fetching canonical transcript for RIT1...
# Fetching canonical transcript for KDM5C...
# Fetching canonical transcript for MAD1L1...
# Fetching canonical transcript for CPS1...
# Fetching canonical transcript for BCL10...
#
# Results saved to abs_ind_gene_canonical_transcripts.xlsx

# %%
# Canonical transcript fetch based on ENSG Id from Ensembl API
# Requires a ensg_id list text file and output filepath

#!/usr/bin/env python

import sys
import json
import time
import pandas as pd
from tqdm import tqdm

try:
    from urllib.parse import urlencode
    from urllib.request import urlopen, Request
    from urllib.error import HTTPError
except ImportError:
    from urlparse import urlparse
    from urllib import urlencode
    from urllib2 import urlopen, Request, HTTPError

class EnsemblRestClient(object):
    def __init__(self, server='http://rest.ensembl.org', reqs_per_sec=15):
        self.server = server
        self.reqs_per_sec = reqs_per_sec
        self.req_count = 0
        self.last_req = 0

    def perform_rest_action(self, endpoint, hdrs=None, params=None):
        """ Perform API request with automatic rate limiting. """
        if hdrs is None:
            hdrs = {}

        if 'Content-Type' not in hdrs:
            hdrs['Content-Type'] = 'application/json'

        if params:
            endpoint += '?' + urlencode(params)

        data = None

        # Rate limit handling
        if self.req_count >= self.reqs_per_sec:
            delta = time.time() - self.last_req
            if delta < 1:
                time.sleep(1 - delta)
            self.last_req = time.time()
            self.req_count = 0

        try:
            request = Request(self.server + endpoint, headers=hdrs)
            response = urlopen(request)
            content = response.read()
            if content:
                data = json.loads(content)
            self.req_count += 1  # Increment request count

        except HTTPError as e:
            if e.code == 429:  # Ensembl rate limiting
                if 'Retry-After' in e.headers:
                    retry = int(e.headers['Retry-After'])
                    print(f"Rate limited. Retrying after {retry} seconds...")
                    time.sleep(retry)
                    return self.perform_rest_action(endpoint, hdrs, params)
            else:
                sys.stderr.write(f"Request failed for {endpoint}: {e.code} {e.reason}\n")

        return data

    def get_canonical_transcript(self, ensg_id):
        """ Fetch canonical transcript for a given ENSG ID. """
        gene_info = self.perform_rest_action(
            endpoint=f'/lookup/id/{ensg_id}', 
            params={}
        )
        if gene_info:
            return gene_info.get("canonical_transcript", "Not available")
        return "No data found"

def fetch_canonical_transcripts(ensg_id_list_file, output_file):
    """ Reads ENSG ID list, fetches canonical transcripts, and saves results. """
    try:
        with open(ensg_id_list_file, 'r') as file:
            ensg_ids = [line.strip() for line in file if line.strip()]
    except FileNotFoundError:
        print(f"Error: File {ensg_id_list_file} not found.")
        sys.exit(1)

    client = EnsemblRestClient()
    results = []

    for ensg_id in tqdm(ensg_ids, desc="Fetching ENSG ID data", unit="ensg_id"):
        canonical_transcript = client.get_canonical_transcript(ensg_id)
        results.append({"ENSG ID": ensg_id, "Canonical Transcript": canonical_transcript})

    # Save results to Excel
    df = pd.DataFrame(results)
    df.to_excel(output_file, index=False)
    print(f"\nResults saved to {output_file}")

if __name__ == '__main__':
    ensg_id_list_file = 'ensgs_abs_ind.txt'  # Update with actual file path
    output_file = 'abs_ind_ensg_canonical_transcripts.xlsx'
    fetch_canonical_transcripts(ensg_id_list_file, output_file)
# Out:
# Fetching ENSG ID data: 100%|██████████| 11/11 [00:05<00:00,  2.06ensg_id/s]
# Results saved to abs_ind_ensg_canonical_transcripts.xlsx

# %%
# p. markup based on canonical transcript matchup on AAChange col
# Requires excel filepath for the canonical transcripts fetched and the annotation file to which p. will be added (it MUST have AAChange col)

import pandas as pd
import re

# Load the provided Excel files
annot_df = pd.read_excel(r"D:\4bc_Gdrive\My Drive\Pathogenic_Landscape\assets\absolute_indie_patho\COMBINED DATA (Absolute plus Indiegene) Table DATASETS for Abstract - Copy.xlsx", sheet_name= "Patho only df")
canonical_df = pd.read_excel(r"D:\4bc_Gdrive\My Drive\Pathogenic_Landscape\code\abs_ind_gene_canonical_transcripts.xlsx")

# Merge the dataframes on 'Ref.Gene' from annot_df and 'Gene Symbol' from canonical_df
merged_df = annot_df.merge(canonical_df, how='left', left_on='Ref.Gene', right_on='Gene Symbol')

# Drop the redundant 'Gene Symbol' column after merge
merged_df.drop(columns=['Gene Symbol'], inplace=True)

# Function to extract p. value for the canonical transcript
def extract_pdot(row):
    # Skip if Canonical Transcript is NaN
    if pd.isnull(row['Canonical Transcript']):
        return None
    
    aa_changes = row['AAChange.ensGene']
    canonical_transcript_id = row['Canonical Transcript'].split('.')[0]

    if pd.notnull(aa_changes):
        aa_changes_list = aa_changes.split(',')
        for change in aa_changes_list:
            if canonical_transcript_id in change:
                match = re.search(r'p\.[A-Za-z]+\d+[A-Za-z]*', change)
                if match:
                    return match.group()
    return None

# Apply the function to create the 'canonical pdots' column
merged_df['Canonical pdots'] = merged_df.apply(extract_pdot, axis=1)

# Save the updated dataframe to a new Excel file
output_file = r"D:\4bc_Gdrive\My Drive\Pathogenic_Landscape\assets\absolute_indie_patho\updated_absolute_patho_data.xlsx"
merged_df.to_excel(output_file, index=False)

print(f"Updated file saved at: {output_file}")
# Out:
# Updated file saved at: D:\4bc_Gdrive\My Drive\Pathogenic_Landscape\assets\absolute_indie_patho\updated_absolute_patho_data.xlsx
